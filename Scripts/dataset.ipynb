# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("odins0n/ucf-crime-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /Users/salvatoremariocarota/.cache/kagglehub/datasets/odins0n/ucf-crime-dataset/1.archive...
#   4%|▍         | 470M/11.0G [01:08<29:39, 6.37MB/s]

# %%
import pandas as pd
import os 

print("File presenti nella cartella:", os.listdir(path))

csv_path = os.path.join(path, "train.csv")
df_train = pd.read_csv(csv_path)
